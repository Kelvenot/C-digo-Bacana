# %% [markdown]
# <a href="https://colab.research.google.com/github/Kelvenot/C-digo-Bacana/blob/main/codigobacana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Loop maneiro
for i in range(1,11):
  print(f"Código maneiro na sua {i} iteração dentro do loop for.")
